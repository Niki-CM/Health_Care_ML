# %% [markdown]
# ### Health Care Project

# %%
#import the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt,seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
#import datasets
df=pd.read_csv("D:\\SimpliLearn DataScience\\Machine Learnings Projects\\projects\\Health Care\\Materials\\health_care_dataset1.csv")

# %% [markdown]
# ###  Basic EDA

# %%
#top5 records
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#bottom 5 records
df.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
#more information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.shape
# Out:
# (303, 14)

# %% [raw]
# Observations:
#     *The dataset includes 303 patients records
#     *there are 13 features ,even though all are nummeric type ,         only 5 are really numeric
#     -->categorocal features:sex,cp,fbs,restecg,exang,slope,ca,thal
#     -->numerical features: age,trestbps,chol,thalach,oldpeak
#
#     *the target is target , 0 represents at low risk ,
#                             1 represents at the high risk
#     *there are no missing values

# %% [markdown]
# ### Data Preprocessing (advance EDA)

# %% [markdown]
# #### check for the null values

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# ####  check for the duplicates

# %%
df[df.duplicated()]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 164   38    1   2       138   175    0        1      173      0      0.0
#
#      slope  ca  thal  target
# 164      2   4     2       1

# %% [raw]
# Observations:
#     *There is one duplicate ,we need to delete it

# %%
df.drop_duplicates(inplace=True)
df.reset_index(drop=True,inplace=True)

# %%
df.shape
# Out:
# (302, 14)

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# ### Outlier

# %%
#outplier presence in the numberic data


plt.figure(figsize=(10,8))  
sns.boxplot(data=df[['age','trestbps','chol','thalach','oldpeak']]);

# %% [raw]
# Observation:
#     *There are some outliers except the age

# %% [markdown]
# ###  find the outlier

# %% [raw]
# #sort inascending order
# #calaculate the 1st and 3rd quartile
# #compute IQR
# #compute the lower bound and upper bound
# #loop

# %%
def detect_outliers_iqr(data):
    outliers_list=[]
    data=sorted(data)
    q1=np.percentile(data,25)
    q3=np.percentile(data,75)
    #inter quartile range
    IQR= q3 - q1
    lower_bound=q1-(1.5*IQR)
    upper_bound=q3+(1.5*IQR)
    
    
    for i in data:
        if(i < lower_bound or i > upper_bound):
            outliers_list.append(i)
    return outliers_list



for i in ['age','trestbps','chol','thalach','oldpeak']:
      outliers=detect_outliers_iqr(df[i])
      print("outliers in:",i,"attribute :",outliers)
# Out:
# outliers in: age attribute : []
# outliers in: trestbps attribute : [172, 174, 178, 178, 180, 180, 180, 192, 200]
# outliers in: chol attribute : [394, 407, 409, 417, 564]
# outliers in: thalach attribute : [71]
# outliers in: oldpeak attribute : [4.2, 4.2, 4.4, 5.6, 6.2]

# %% [raw]
# Observation:
# *outliers in: age attribute : []
# *outliers in: trestbps attribute : [172, 174, 178, 178, 180, 180, 180, 192, 200]
# *outliers in: chol attribute : [394, 407, 409, 417, 564]
# *outliers in: thalach attribute : [71]
# *outliers in: oldpeak attribute : [4.2, 4.2, 4.4, 5.6, 6.2]

# %% [markdown]
# ### handeling the outliers

# %%
#handling the outliers based on the flooring and capping method

def handel_outliers(data):
    
    tenth_percentile=np.percentile(data,10)
    ninetieth_percentile=np.percentile(data,90)
    
    print("10th ,tenth_percentile",tenth_percentile)
    print("90th , ninetieth_percentile",ninetieth_percentile)
    
    b=np.where(data < tenth_percentile ,tenth_percentile,data)
    
    b1=np.where(b > ninetieth_percentile ,ninetieth_percentile,b)
    return b1


for i in ['trestbps','chol','thalach','oldpeak']:
    df[i]=handel_outliers(df[i])
    print(df[i])
# Out:
# 10th ,tenth_percentile 110.0
# 90th , ninetieth_percentile 152.0
# 0      145.0
# 1      130.0
# 2      130.0
# 3      120.0
# 4      120.0
#        ...
# 297    140.0
# 298    110.0
# 299    144.0
# 300    130.0
# 301    130.0
# Name: trestbps, Length: 302, dtype: float64
# 10th ,tenth_percentile 188.4
# 90th , ninetieth_percentile 308.90000000000003
# 0      233.0
# 1      250.0
# 2      204.0
# 3      236.0
# 4      308.9
#        ...
# 297    241.0
# 298    264.0
# 299    193.0
# 300    188.4
# 301    236.0
# Name: chol, Length: 302, dtype: float64
# 10th ,tenth_percentile 116.0
# 90th , ninetieth_percentile 176.80000000000007
# 0      150.0
# 1      176.8
# 2      172.0
# 3      176.8
# 4      163.0
#        ...
# 297    123.0
# 298    132.0
# 299    141.0
# 300    116.0
# 301    174.0
# Name: thalach, Length: 302, dtype: float64
# 10th ,tenth_percentile 0.0
# 90th , ninetieth_percentile 2.8
# 0      2.3
# 1      2.8
# 2      1.4
# 3      0.8
# 4      0.6
#       ...
# ...

# %%
#check again with  the boxplot

plt. figure(figsize=(10,8))
sns.boxplot(data=df[['age','trestbps','chol','thalach','oldpeak']]);

# %% [markdown]
# observation:
# outliers are clear

# %% [markdown]
# ### visualization

# %%
sns.histplot(df.age)
plt.title("age  distribution of patients")
plt.show()

# %%
df.sex.value_counts().to_frame()
# Out:
#      count
# sex
# 1      206
# 0       96

# %%
#count_plot
sns.countplot(df,x="sex")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.barplot(df,x="sex",y="cp")
# Out:
# <Axes: xlabel='sex', ylabel='cp'>

# %%
sns.histplot(df.cp)
plt.title("chect pain typw distribution")
plt.show()

# %%
df.cp.value_counts()
# Out:
# cp
# 0    143
# 2     86
# 1     50
# 3     23
# Name: count, dtype: int64

# %% [markdown]
# 1 = typical angina; 2 = atypical angina; 3 = non-anginal pain; 0 = asymptomatic

# %%
#resting blood pressure
sns.histplot(df,x='trestbps')
plt.title("blood pressure distribution")
plt.show()

# %%
#cholesterol
sns.histplot(df.chol)
plt.title("cholesterol level distribution")
plt.show()

# %% [raw]
# Cholesterol, mg/dl	Interpretation
# < 200	            Desirable
# 200-239	            Borderline
# > 240	            High

# %%
#fasting blood sugar
df.fbs.value_counts().to_frame()
# Out:
#      count
# fbs
# 0      257
# 1       45

# %% [markdown]
# observation:
#     *Reminder: 0 means less or equal to 120 mg/dl (which is good), 1 means higher than 120 mg/dl.
#
# *The majority of the patients don't have serious sugar problems.

# %%
#maxixmum heart rate acheived
sns.histplot(df.thalach)
plt.title("maximum heart rate acheived distribution")
plt.show()

# %%
#slope of the peak exercise ST segemnt
sns.histplot(df,x='slope')
plt.title("the slope of the peak exercise St segment distibution")
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
#the chance of heart attack
df.target.value_counts().to_frame()
# Out:
#         count
# target
# 1         164
# 0         138

# %%
#finding  the correlation
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True,cmap='bwr')
plt.title("correlation map")
plt.show()

# %% [raw]
# From the above heatmap we can say
# cp,thalach, are having the positive correlation
# exang,oldpeak,ca having the neagative correlation

# %%
#pair plot- it is used to find the linear relationship  for numeric columns

sns.pairplot(df[['age','trestbps','chol','thalach','oldpeak','target']],hue='target')

# %% [raw]
# From the above pair plot we can comclude that dataset is not linearly seperable

# %% [raw]
# conclusion:
#
# 1.The majority of the patients are older than 40.
#
# 2.In the dataset there are 2 times more males than females.
#
# 3.54.3% of the patients have a high risk of heart attack, 45.7% - low risk of a heart attack.
#
# 4.Age distribution of patients from the high-risk group has a peak at 57-58 ages.
#
# 5.The major factors influencing heart attacks are: Chest pain, Maximum heart rate achieved, Exercise induced angina, ST depression induced by exercise relative to rest and Number of major vessels

# %% [markdown]
# ### Feature scaling

# %%
df.head()
# Out:
#    age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   63    1   3     145.0  233.0    1        0    150.0      0      2.3
# 1   37    1   2     130.0  250.0    0        1    176.8      0      2.8
# 2   41    0   1     130.0  204.0    0        0    172.0      0      1.4
# 3   56    1   1     120.0  236.0    0        1    176.8      0      0.8
# 4   57    0   0     120.0  308.9    0        1    163.0      1      0.6
#
#    slope  ca  thal  target
# 0      0   0     1       1
# 1      0   0     2       1
# 2      2   0     2       1
# 3      2   0     2       1
# 4      2   0     2       1

# %%
from sklearn.preprocessing import MinMaxScaler


scale=MinMaxScaler()
df[['age','trestbps','chol','thalach','oldpeak']]=scale.fit_transform(df[['age','trestbps','chol','thalach','oldpeak']])

# %%
df.head()
# Out:
#         age  sex  cp  trestbps      chol  fbs  restecg   thalach  exang  \
# 0  0.708333    1   3  0.833333  0.370124    1        0  0.559211      0
# 1  0.166667    1   2  0.476190  0.511203    0        1  1.000000      0
# 2  0.250000    0   1  0.476190  0.129461    0        0  0.921053      0
# 3  0.562500    1   1  0.238095  0.395021    0        1  1.000000      0
# 4  0.583333    0   0  0.238095  1.000000    0        1  0.773026      1
#
#     oldpeak  slope  ca  thal  target
# 0  0.821429      0   0     1       1
# 1  1.000000      0   0     2       1
# 2  0.500000      2   0     2       1
# 3  0.285714      2   0     2       1
# 4  0.214286      2   0     2       1

# %% [markdown]
# ### Data prepartion

# %%
from sklearn.model_selection import train_test_split

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
#divide the data into features and target variable

feature_cols = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
       'exang', 'oldpeak', 'slope', 'ca', 'thal',]
x = df[feature_cols] 
y = df.target

# %%
#splitting
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train.shape,x_test.shape
# Out:
# ((241, 13), (61, 13))

# %%
y_train.shape,y_test.shape
# Out:
# ((241,), (61,))

# %% [markdown]
# # classification modles

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble  import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score,recall_score,f1_score

# %%
# !pip install xgboost

# %%
from xgboost import  XGBClassifier

# %% [markdown]
# ### Logistic regression

# %%
#Logistic regression  and train the data
clf=LogisticRegression().fit(x_train,y_train)

#prediction on the test data
y_pred=clf.predict(x_test)

#accuraacy
dt_accuracy=round(metrics.accuracy_score(y_test, y_pred)*100,2)
print("\nAccuracy:",dt_accuracy,'%')


print(metrics.classification_report(y_test, y_pred))
# Out:
# Accuracy: 90.16 %
#               precision    recall  f1-score   support
#
#            0       0.93      0.86      0.89        29
#            1       0.88      0.94      0.91        32
#
#     accuracy                           0.90        61
#    macro avg       0.90      0.90      0.90        61
# weighted avg       0.90      0.90      0.90        61

# %% [markdown]
# ###  Decision Tree Classifier

# %%
clf = DecisionTreeClassifier(criterion="entropy", max_depth=10)

# Train Decision Tree Classifer
clf = clf.fit(x_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(x_test)

# Accuracy
dt_accuracy=round(metrics.accuracy_score(y_test, y_pred)*100,2)
print("\nAccuracy:",dt_accuracy,'%')


print(metrics.classification_report(y_test, y_pred))
# Out:
# Accuracy: 78.69 %
#               precision    recall  f1-score   support
#
#            0       0.79      0.76      0.77        29
#            1       0.79      0.81      0.80        32
#
#     accuracy                           0.79        61
#    macro avg       0.79      0.79      0.79        61
# weighted avg       0.79      0.79      0.79        61

# %% [markdown]
# ### SVM classifier

# %%
clf = svm.SVC() # Create SVM classifier

# Train the dataset
clf = clf.fit(x_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(x_test)

# Accuracy
svm_accuracy=round(metrics.accuracy_score(y_test, y_pred)*100,2)
print("\nAccuracy:",dt_accuracy,'%')


print(metrics.classification_report(y_test, y_pred))
# Out:
# Accuracy: 78.69 %
#               precision    recall  f1-score   support
#
#            0       0.96      0.79      0.87        29
#            1       0.84      0.97      0.90        32
#
#     accuracy                           0.89        61
#    macro avg       0.90      0.88      0.88        61
# weighted avg       0.90      0.89      0.88        61

# %% [markdown]
# ### Random forest classifier

# %%
# Random Forest

clf=RandomForestClassifier(n_estimators=100,criterion =  "entropy")

# Train the dataset
clf = clf.fit(x_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(x_test)

# Accuracy
rf_accuracy=round(metrics.accuracy_score(y_test, y_pred)*100,2)
print("\nAccuracy:",dt_accuracy,'%')


print(metrics.classification_report(y_test, y_pred))
# Out:
# Accuracy: 78.69 %
#               precision    recall  f1-score   support
#
#            0       0.92      0.83      0.87        29
#            1       0.86      0.94      0.90        32
#
#     accuracy                           0.89        61
#    macro avg       0.89      0.88      0.88        61
# weighted avg       0.89      0.89      0.88        61

# %% [markdown]
# ### XGBoost

# %%
# XGBoost

clf=XGBClassifier(n_estimators=30)

# Train the dataset
clf = clf.fit(x_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(x_test)

# Accuracy
xgb_accuracy=round(metrics.accuracy_score(y_test, y_pred)*100,2)
print("\nAccuracy:",dt_accuracy,'%')


print(metrics.classification_report(y_test, y_pred))
# Out:
# Accuracy: 78.69 %
#               precision    recall  f1-score   support
#
#            0       0.88      0.79      0.84        29
#            1       0.83      0.91      0.87        32
#
#     accuracy                           0.85        61
#    macro avg       0.86      0.85      0.85        61
# weighted avg       0.86      0.85      0.85        61

# %%
model_ev = pd.DataFrame({'Model':['LR','RF','XGB','DT','SVM'],
                    'Accuracy %':[lr_accuracy,rf_accuracy,xgb_accuracy,dt_accuracy,svm_accuracy]
                                })

model_ev.sort_values(by='Accuracy %')
model_ev
# Out:
#   Model  Accuracy %
# 0    LR       90.16
# 1    RF       88.52
# 2   XGB       85.25
# 3    DT       78.69
# 4   SVM       88.52

# %%
sns.barplot(x='Model',y='Accuracy %',data=model_ev);
